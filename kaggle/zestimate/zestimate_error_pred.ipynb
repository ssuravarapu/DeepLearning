# %%
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import Imputer, StandardScaler
from keras import models
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras.wrappers.scikit_learn import KerasRegressor
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load Training Data

# %%
data = pd.read_csv('train_data.csv')
data.head()
# Out:
#    Unnamed: 0  logerror  airconditioningtypeid  architecturalstyletypeid  \
# 0           0    0.0276                    1.0                       NaN
# 1           1   -0.1684                    NaN                       NaN
# 2           2   -0.0040                    1.0                       NaN
# 3           3    0.0218                    1.0                       NaN
# 4           4   -0.0050                    NaN                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          2.0         3.0                  NaN
# 1           NaN          3.5         4.0                  NaN
# 2           NaN          3.0         2.0                  NaN
# 3           NaN          2.0         2.0                  NaN
# 4           NaN          2.5         4.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr         ...           \
# 0                    4.0                2.0         ...
# 1                    NaN                3.5         ...
# 2                    4.0                3.0         ...
# 3                    4.0                2.0         ...
# 4                    NaN                2.5         ...
#
#    yardbuildingsqft26  yearbuilt  numberofstories  structuretaxvaluedollarcnt  \
# 0                 NaN     1959.0              NaN                    122754.0
# 1                 NaN     2014.0              NaN                    346458.0
# 2                 NaN     1940.0              NaN                     61994.0
# 3                 NaN     1987.0              NaN                    171518.0
# 4                 NaN     1981.0              2.0                    169574.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           360170.0          2015.0               237416.0    6735.88
# 1           585529.0          2015.0               239071.0   10153.02
# 2           119906.0          2015.0                57912.0   11484.48
# 3           244880.0          2015.0                73362.0    3048.74
# 4           434551.0          2015.0               264977.0    5488.96
#
#    taxdelinquencyyear  censustractandblock
# 0                 NaN         6.037107e+13
# 1                 NaN                  NaN
# 2                 NaN         6.037464e+13
# 3                 NaN         6.037296e+13
# 4                 NaN         6.059042e+13
#
# [5 rows x 54 columns]

# %%
data.shape
# Out:
# (90275, 54)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90275 entries, 0 to 90274
# Data columns (total 54 columns):
# Unnamed: 0                      90275 non-null int64
# logerror                        90275 non-null float64
# airconditioningtypeid           28781 non-null float64
# architecturalstyletypeid        261 non-null float64
# basementsqft                    43 non-null float64
# bathroomcnt                     90275 non-null float64
# bedroomcnt                      90275 non-null float64
# buildingclasstypeid             16 non-null float64
# buildingqualitytypeid           57364 non-null float64
# calculatedbathnbr               89093 non-null float64
# decktypeid                      658 non-null float64
# finishedfloor1squarefeet        6856 non-null float64
# calculatedfinishedsquarefeet    89614 non-null float64
# finishedsquarefeet12            85596 non-null float64
# finishedsquarefeet13            33 non-null float64
# finishedsquarefeet15            3564 non-null float64
# finishedsquarefeet50            6856 non-null float64
# finishedsquarefeet6             421 non-null float64
# fips                            90275 non-null float64
# fireplacecnt                    9607 non-null float64
# fullbathcnt                     89093 non-null float64
# garagecarcnt                    29937 non-null float64
# garagetotalsqft                 29937 non-null float64
# heatingorsystemtypeid           56080 non-null float64
# latitude                        90275 non-null float64
# longitude                       90275 non-null float64
# lotsizesquarefeet               80125 non-null float64
# poolcnt                         17901 non-null float64
# poolsizesum                     969 non-null float64
# pooltypeid10                    1161 non-null float64
# pooltypeid2                     1204 non-null float64
# pooltypeid7                     16697 non-null float64
# propertylandusetypeid           90275 non-null float64
# rawcensustractandblock          90275 non-null float64
# regionidcity                    88472 non-null float64
# regionidcounty                  90275 non-null float64
# regionidneighborhood            36012 non-null float64
# regionidzip                     90240 non-null float64
# roomcnt                         90275 non-null float64
# storytypeid                     43 non-null float64
# threequarterbathnbr             12009 non-null float64
# typeconstructiontypeid          299 non-null float64
# unitcnt                         58353 non-null float64
# yardbuildingsqft17              2646 non-null float64
# yardbuildingsqft26              95 non-null float64
# yearbuilt                       89519 non-null float64
# numberofstories                 20570 non-null float64
# structuretaxvaluedollarcnt      89895 non-null float64
# taxvaluedollarcnt               90274 non-null float64
# assessmentyear                  90275 non-null float64
# landtaxvaluedollarcnt           90274 non-null float64
# taxamount                       90269 non-null float64
# taxdelinquencyyear              1783 non-null float64
# censustractandblock             89670 non-null float64
# dtypes: float64(53), int64(1)
# memory usage: 37.2 MB

# %%
data.describe()
# Out:
#          Unnamed: 0      logerror  airconditioningtypeid  \
# count  90275.000000  90275.000000           28781.000000
# mean   45137.000000      0.011457               1.816372
# std    26060.292113      0.161079               2.974168
# min        0.000000     -4.605000               1.000000
# 25%    22568.500000     -0.025300               1.000000
# 50%    45137.000000      0.006000               1.000000
# 75%    67705.500000      0.039200               1.000000
# max    90274.000000      4.737000              13.000000
#
#        architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                261.000000     43.000000  90275.000000  90275.000000
# mean                   7.229885    713.581395      2.279474      3.031869
# std                    2.716196    437.434198      1.004271      1.156436
# min                    2.000000    100.000000      0.000000      0.000000
# 25%                    7.000000    407.500000      2.000000      2.000000
# 50%                    7.000000    616.000000      2.000000      3.000000
# 75%                    7.000000    872.000000      3.000000      4.000000
# max                   21.000000   1555.000000     20.000000     16.000000
#
#        buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# count                 16.0           57364.000000       89093.000000
# mean                   4.0               5.565407           2.309216
# std                    0.0               1.900602           0.976172
# min                    4.0               1.000000           1.000000
# 25%                    4.0               4.000000           2.000000
# 50%                    4.0               7.000000           2.000000
# 75%                    4.0               7.000000           3.000000
# max                    4.0              12.000000          20.000000
#
#               ...           yardbuildingsqft26     yearbuilt  numberofstories  \
# count         ...                    95.000000  89519.000000     20570.000000
# mean          ...                   311.694737   1968.532870         1.440739
# std           ...                   346.354850     23.763475         0.544498
# min           ...                    18.000000   1885.000000         1.000000
# 25%           ...                   100.000000   1953.000000         1.000000
# 50%           ...                   159.000000   1970.000000         1.000000
# 75%           ...                   361.000000   1987.000000         2.000000
# max           ...                  1366.000000   2015.000000         4.000000
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# count                8.989500e+04       9.027400e+04         90275.0
# mean                 1.800934e+05       4.576726e+05          2015.0
# std                  2.091299e+05       5.548844e+05             0.0
# min                  1.000000e+02       2.200000e+01          2015.0
# 25%                  8.124500e+04       1.990232e+05          2015.0
# 50%                  1.320000e+05       3.428720e+05          2015.0
# 75%                  2.105345e+05       5.405890e+05          2015.0
# max                  9.948100e+06       2.775000e+07          2015.0
#
#        landtaxvaluedollarcnt      taxamount  taxdelinquencyyear  \
# count           9.027400e+04   90269.000000         1783.000000
# mean            2.783353e+05    5983.975927           13.402692
# std             4.004955e+05    6838.876956            2.715966
# min             2.200000e+01      49.080000            6.000000
# 25%             8.222800e+04    2872.830000           13.000000
# 50%             1.929700e+05    4542.750000           14.000000
# 75%             3.454195e+05    6901.090000           15.000000
# max             2.450000e+07  321936.090000           99.000000
#
#        censustractandblock
# count         8.967000e+04
# mean          6.049151e+13
# std           2.046605e+11
# min           6.037101e+13
# 25%           6.037320e+13
# 50%           6.037615e+13
# 75%           6.059042e+13
# max           6.111009e+13
#
# [8 rows x 54 columns]

# %%
missing_df = data.isnull().sum(axis=0).reset_index()
missing_df.columns = ['column_name', 'missing_count']
missing_df['missing_ratio'] = missing_df['missing_count'] / data.shape[0]
del_cols = missing_df.loc[missing_df['missing_ratio']>0.6]['column_name']

# %%
data.drop(list(del_cols), axis=1, inplace=True)

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90275 entries, 0 to 90274
# Data columns (total 27 columns):
# logerror                        90275 non-null float64
# bathroomcnt                     90275 non-null float64
# bedroomcnt                      90275 non-null float64
# buildingqualitytypeid           57364 non-null float64
# calculatedbathnbr               89093 non-null float64
# calculatedfinishedsquarefeet    89614 non-null float64
# finishedsquarefeet12            85596 non-null float64
# fips                            90275 non-null float64
# fullbathcnt                     89093 non-null float64
# heatingorsystemtypeid           56080 non-null float64
# latitude                        90275 non-null float64
# longitude                       90275 non-null float64
# lotsizesquarefeet               80125 non-null float64
# propertylandusetypeid           90275 non-null float64
# rawcensustractandblock          90275 non-null float64
# regionidcity                    88472 non-null float64
# regionidcounty                  90275 non-null float64
# regionidzip                     90240 non-null float64
# roomcnt                         90275 non-null float64
# unitcnt                         58353 non-null float64
# yearbuilt                       89519 non-null float64
# structuretaxvaluedollarcnt      89895 non-null float64
# taxvaluedollarcnt               90274 non-null float64
# assessmentyear                  90275 non-null float64
# landtaxvaluedollarcnt           90274 non-null float64
# taxamount                       90269 non-null float64
# censustractandblock             89670 non-null float64
# dtypes: float64(27)
# memory usage: 18.6 MB

# %%
data.fillna(data.mean(), inplace=True)
# Out:
#        logerror  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0        0.0276          2.0         3.0               4.000000
# 1       -0.1684          3.5         4.0               5.565407
# 2       -0.0040          3.0         2.0               4.000000
# 3        0.0218          2.0         2.0               4.000000
# 4       -0.0050          2.5         4.0               5.565407
# 5       -0.2705          4.0         4.0               1.000000
# 6        0.0440          1.0         2.0               7.000000
# 7        0.1638          2.5         3.0               5.565407
# 8       -0.0030          1.0         2.0               5.565407
# 9        0.0843          2.0         2.0               5.565407
# 10       0.3825          2.0         2.0               7.000000
# 11      -0.0161          4.0         5.0               1.000000
# 12       0.0344          2.0         3.0               7.000000
# 13       0.0816          2.0         2.0               5.565407
# 14      -0.0450          2.0         2.0               5.565407
# 15       0.0020          2.0         3.0               5.565407
# 16       0.0440          2.5         3.0               5.565407
# 17      -0.0419          1.0         1.0               7.000000
# 18      -0.0020          2.0         3.0               5.565407
# 19       0.0100          3.0         3.0               4.000000
# 20      -0.0387          1.0         2.0               7.000000
# 21       0.0218          2.0         2.0               5.565407
# 22       0.0149          2.0         4.0               5.565407
# 23       0.1151          4.0         3.0               4.000000
# 24      -0.1696          2.5         2.0               5.565407
# 25      -0.0440          4.0         3.0               7.000000
# 26      -0.0747          2.0         2.0               4.000000
# 27       0.0080          2.5         2.0               5.565407
# 28       0.0010          2.0         2.0               4.000000
# 29      -0.0534          3.0         2.0               4.000000
# ...         ...          ...         ...                    ...
# 90245    0.0953          3.0         3.0               4.000000
# 90246    0.0139          2.0         2.0               5.565407
# 90247    0.2095          2.0         2.0               4.000000
# 90248    0.0080          2.5         4.0               5.565407
# 90249   -0.1312          1.0         1.0               7.000000
# 90250    0.0421          2.0         3.0               5.565407
# 90251    0.0658          1.0         3.0               7.000000
# 90252    0.0030          3.0         3.0               7.000000
# 90253   -0.0294          2.0         2.0               7.000000
# 90267                2.0                        1830.0           1830.000000
# 90268                3.0                        2438.0           2438.000000
# 90269                2.0                        1448.0           1448.000000
# 90270                1.0                         653.0            653.000000
# 90271                3.0                        2856.0           2856.000000
# 90272                2.0                        2617.0           1745.454531
# 90273                2.0                        1034.0           1034.000000
# 90274                1.0                        1524.0           1524.000000
#
#          fips  fullbathcnt  heatingorsystemtypeid         ...           \
# 0      6037.0          2.0               2.000000         ...
# 1      6059.0          3.0               3.926979         ...
# 2      6037.0          3.0               2.000000         ...
# 3      6037.0          2.0               2.000000         ...
# 4      6059.0          2.0               3.926979         ...
# 5      6037.0          4.0               2.000000         ...
# 6      6037.0          1.0               7.000000         ...
# 7      6111.0          2.0               3.926979         ...
# 8      6059.0          1.0               3.926979         ...
# 9      6059.0          2.0               3.926979         ...
# 10     6037.0          2.0               2.000000         ...
# 11     6037.0          4.0               2.000000         ...
# 12     6037.0          2.0               7.000000         ...
# 13     6059.0          2.0               3.926979         ...
# 14     6059.0          2.0               3.926979         ...
# 15     6059.0          2.0               6.000000         ...
# 16     6111.0          2.0               3.926979         ...
# 17     6037.0          1.0               2.000000         ...
# 18     6059.0          2.0               3.926979         ...
# 19     6037.0          3.0               2.000000         ...
# 20     6037.0          1.0               7.000000         ...
# 21     6059.0          2.0               3.926979         ...
# 22     6059.0          2.0               3.926979         ...
# 23     6037.0          4.0               2.000000         ...
# 24     6059.0          2.0               3.926979         ...
# 25     6037.0          4.0               2.000000         ...
# 26     6037.0          2.0               2.000000         ...
# 27     6059.0          2.0               6.000000         ...
# 28     6037.0          2.0               2.000000         ...
# 29     6037.0          3.0               2.000000         ...
# ...       ...          ...                    ...         ...
# 90245  6037.0          3.0               2.000000         ...
# 90246  6037.0          2.0               2.000000         ...
# 90247  6037.0          2.0               2.000000         ...
# 90248  6059.0          2.0               3.926979         ...
# 90249  6037.0          1.0               7.000000         ...
# 90250  6059.0          2.0               3.926979         ...
# 90251  6037.0          1.0               7.000000         ...
# 90252  6037.0          3.0               2.000000         ...
# 90253  6037.0          2.0               2.000000         ...
# 90254  6037.0          2.0               2.000000         ...
# 90255  6037.0          3.0               2.000000         ...
# 90256  6059.0          2.0               3.926979         ...
# 90257  6037.0          2.0               2.000000         ...
# 90258  6037.0          3.0               2.000000         ...
# 90259  6037.0          2.0               2.000000         ...
# 90260  6037.0          2.0               2.000000         ...
# 90261  6037.0          1.0               2.000000         ...
# 90262  6037.0          2.0               2.000000         ...
# 90263  6037.0          2.0               2.000000         ...
# 90264  6037.0          3.0               2.000000         ...
# 90265  6037.0          1.0               2.000000         ...
# 90266  6037.0          2.0               3.926979         ...
# 90267  6111.0          2.0               3.926979         ...
# 90268  6037.0          3.0               2.000000         ...
# 90269  6037.0          2.0               2.000000         ...
# 90270  6037.0          1.0               2.000000         ...
# 90271  6037.0          3.0               2.000000         ...
# 90272  6037.0          2.0               3.926979         ...
# 90273  6037.0          2.0               2.000000         ...
# 90274  6037.0          1.0               7.000000         ...
#
#        regionidzip  roomcnt   unitcnt  yearbuilt  structuretaxvaluedollarcnt  \
#
# 90271           161111.0          2015.0                43218.0    1886.54
# 90272            38096.0          2015.0                16088.0    1925.70
# 90273           165869.0          2015.0                32878.0    2285.57
# 90274           163037.0          2015.0                96779.0    2560.96
#
#        censustractandblock
# 0             6.037107e+13
# 1             6.049151e+13
# 2             6.037464e+13
# 3             6.037296e+13
# 4             6.059042e+13
# 5             6.037621e+13
# 6             6.037542e+13
# 7             6.111003e+13
# 8             6.059042e+13
# 9             6.059063e+13
# 10            6.037141e+13
# 11            6.037263e+13
# 12            6.037311e+13
# 13            6.059063e+13
# 14            6.059002e+13
# 15            6.059099e+13
# 16            6.111007e+13
# 17            6.037575e+13
# 18            6.059100e+13
# 19            6.037140e+13
# 20            6.037570e+13
# 21            6.059075e+13
# 22            6.059110e+13
# 23            6.037277e+13
# 24            6.059089e+13
# 25            6.037504e+13
# 26            6.037910e+13
# 27            6.059042e+13
# 28            6.037140e+13
# 29            6.037577e+13
# ...                    ...
# 90245         6.037137e+13
# 90246         6.037576e+13
# 90247         6.037234e+13
# 90248         6.059052e+13
# 90249         6.037920e+13
# 90250         6.059100e+13
# 90251         6.037553e+13
# 90252         6.037553e+13
# 90253         6.037901e+13
# 90254         6.037553e+13
# 90255         6.037901e+13
# 90256         6.059052e+13
# 90257         6.037800e+13
# 90258         6.037213e+13
# 90259         6.037192e+13
# 90260         6.037604e+13
# 90261         6.037232e+13
# 90262         6.037107e+13
# 90263         6.037302e+13
# 90264         6.037801e+13
# 90265         6.037302e+13
# 90266         6.037543e+13
# 90267         6.111002e+13
# 90268         6.037541e+13
# 90269         6.037404e+13
# 90270         6.037132e+13
# 90271         6.037301e+13
# 90272         6.037433e+13
# 90273         6.037601e+13
# 90274         6.037544e+13
#
# [90275 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90275 entries, 0 to 90274
# Data columns (total 27 columns):
# logerror                        90275 non-null float64
# bathroomcnt                     90275 non-null float64
# bedroomcnt                      90275 non-null float64
# buildingqualitytypeid           90275 non-null float64
# calculatedbathnbr               90275 non-null float64
# calculatedfinishedsquarefeet    90275 non-null float64
# finishedsquarefeet12            90275 non-null float64
# fips                            90275 non-null float64
# fullbathcnt                     90275 non-null float64
# heatingorsystemtypeid           90275 non-null float64
# latitude                        90275 non-null float64
# longitude                       90275 non-null float64
# lotsizesquarefeet               90275 non-null float64
# propertylandusetypeid           90275 non-null float64
# rawcensustractandblock          90275 non-null float64
# regionidcity                    90275 non-null float64
# regionidcounty                  90275 non-null float64
# regionidzip                     90275 non-null float64
# roomcnt                         90275 non-null float64
# unitcnt                         90275 non-null float64
# yearbuilt                       90275 non-null float64
# structuretaxvaluedollarcnt      90275 non-null float64
# taxvaluedollarcnt               90275 non-null float64
# assessmentyear                  90275 non-null float64
# landtaxvaluedollarcnt           90275 non-null float64
# taxamount                       90275 non-null float64
# censustractandblock             90275 non-null float64
# dtypes: float64(27)
# memory usage: 18.6 MB

# %% [markdown]
# ## Feature Selection

# %%
X = data.drop(['logerror'], axis=1)

# %%
y = data['logerror']

# %%
(X.shape, y.shape)
# Out:
# ((90275, 26), (90275,))

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor

# %%
rfe = RFE(DecisionTreeRegressor(), 8)
fit = rfe.fit(X, y)

# %%
fit.support_
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#         True,  True,  True, False, False, False, False, False, False,
#        False, False,  True,  True, False,  True,  True, False], dtype=bool)

# %%
fit.ranking_
# Out:
# array([12,  8,  9, 10,  1,  4, 18, 14, 15,  1,  1,  1, 11,  7,  6, 16,  3,
#        13, 17,  2,  1,  1, 19,  1,  1,  5])

# %%
X = data[['bedroomcnt','calculatedfinishedsquarefeet','latitude', 'longitude', 'lotsizesquarefeet', 
          'structuretaxvaluedollarcnt', 'taxvaluedollarcnt','landtaxvaluedollarcnt','taxamount', 'yearbuilt']]

# %%
X.head()
# Out:
#    bedroomcnt  calculatedfinishedsquarefeet    latitude    longitude  \
# 0         3.0                        1684.0  34280990.0 -118488536.0
# 1         4.0                        2263.0  33668120.0 -117677556.0
# 2         2.0                        2217.0  34136312.0 -118175032.0
# 3         2.0                         839.0  33755800.0 -118309000.0
# 4         4.0                        2283.0  33485643.0 -117700234.0
#
#    lotsizesquarefeet  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0             7528.0                    122754.0           360170.0
# 1             3643.0                    346458.0           585529.0
# 2            11423.0                     61994.0           119906.0
# 3            70859.0                    171518.0           244880.0
# 4             6000.0                    169574.0           434551.0
#
#    landtaxvaluedollarcnt  taxamount  yearbuilt
# 0               237416.0    6735.88     1959.0
# 1               239071.0   10153.02     2014.0
# 2                57912.0   11484.48     1940.0
# 3                73362.0    3048.74     1987.0
# 4               264977.0    5488.96     1981.0

# %% [markdown]
# ## Training Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Decision Tree

# %%
dtree = DecisionTreeRegressor()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred = dtree.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# -1.0001341417099785

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators=800, max_depth=8)

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=8,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_pred = rfr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.0089317308855977329

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()

# %%
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
y_pred = gbr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.0070171587345255748

# %% [markdown]
# ### Model Architecture

# %%
model = Sequential()

model.add(Dense(300, input_dim=X.shape[1], activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(25, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mae')

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_92 (Dense)             (None, 300)               3300
# _________________________________________________________________
# dense_93 (Dense)             (None, 200)               60200
# _________________________________________________________________
# dense_94 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dense_95 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_96 (Dense)             (None, 25)                1275
# _________________________________________________________________
# dense_97 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 89,951
# Trainable params: 89,951
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Execute Model and Predict

# %%
model.fit(X_train, y_train, epochs=15, batch_size=32, verbose=2)
# Out:
# Epoch 1/15
# 6s - loss: 0.0683
# Epoch 2/15
# 5s - loss: 0.0678
# Epoch 3/15
# 5s - loss: 0.0677
# Epoch 4/15
# 5s - loss: 0.0677
# Epoch 5/15
# 5s - loss: 0.0676
# Epoch 6/15
# 5s - loss: 0.0676
# Epoch 7/15
# 5s - loss: 0.0676
# Epoch 8/15
# 5s - loss: 0.0676
# Epoch 9/15
# 5s - loss: 0.0675
# Epoch 10/15
# 5s - loss: 0.0675
# Epoch 11/15
# 5s - loss: 0.0675
# Epoch 12/15
# 5s - loss: 0.0674
# Epoch 13/15
# 5s - loss: 0.0674
# Epoch 14/15
# 6s - loss: 0.0674
# Epoch 15/15
# 5s - loss: 0.0673

# %%
score = model.evaluate(X_test, y_test, batch_size=16)
print("\n")
print(score)

y_pred = model.predict(X_test, batch_size=16)

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 22128/22569 [============================>.] - ETA: 0s
#
# 0.0682949297253
# 0.0044720819706025594
